# %% [markdown]
# 10-second video. Close-up shots of screens on a dark desk. No people. Screen glow only. 4K.
#
# 0–3s: Laptop showing a website being designed in Figma — dark layout, purple accents, cursor adjusting a component.
# 3–6s: Phone showing WhatsApp Business — automated bot replies arriving one by one.
# 6–9s: Laptop showing a dark Shopify store — product grid, a sale notification pops in the corner.
# 9–10s: Fade to black.
